# %% [markdown]
# <a href="https://colab.research.google.com/github/abidahnisaa/Project_Breast_Cancer_Poster_Presentation_UNS/blob/main/Filtering_DepMap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re

# %%
df_raw = pd.read_csv("/content/drive/MyDrive/Breast Cancer Model/CRISPR_(DepMap_Public_26Q1+Score,_Chronos)_subsetted.csv")

df_raw.shape
df_raw.head(10)
# Out:
# /tmp/ipykernel_1013/657553033.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv("/content/drive/MyDrive/Breast Cancer Model/CRISPR_(DepMap_Public_26Q1+Score,_Chronos)_subsetted.csv")
#     depmap_id cell_line_display_name              lineage_1  \
# 0  ACH-001270                 127399            Soft Tissue
# 1  ACH-002680                170MGBA              CNS/Brain
# 2  ACH-002400                  21MT1                 Breast
# 3  ACH-002401                  21MT2                 Breast
# 4  ACH-002399                   21NT                 Breast
# 5  ACH-003587                 531MII                   Bone
# 6  ACH-000520                    59M   Ovary/Fallopian Tube
# 7  ACH-000973                   639V  Bladder/Urinary Tract
# 8  ACH-001795                 94T778            Soft Tissue
# 9  ACH-001999                9505BIK               Pancreas
#
#                    lineage_2                         lineage_3 lineage_6  \
# 0           Synovial Sarcoma                  Synovial Sarcoma       NaN
# 1  Adult-Type Diffuse Glioma        Glioblastoma, IDH-Wildtype       NaN
# 2  Invasive Breast Carcinoma  Breast Invasive Ductal Carcinoma     HER2+
# 3  Invasive Breast Carcinoma  Breast Invasive Ductal Carcinoma     HER2+
# 4  Invasive Breast Carcinoma  Breast Invasive Ductal Carcinoma     HER2+
# 5               Osteosarcoma                      Osteosarcoma       NaN
# 6   Ovarian Epithelial Tumor  High-Grade Serous Ovarian Cancer       NaN
# 7            Urethral Cancer     Urethral Urothelial Carcinoma       NaN
# 8                Liposarcoma   Well-Differentiated Liposarcoma       NaN
# 9  Pancreatic Adenocarcinoma         Pancreatic Adenocarcinoma       NaN
#
#    lineage_4      A1BG      AASS    ABCA10  ...    ZNF432    ZNF516   ZNF518A  \
# 0        NaN -0.038756 -0.215523  0.044912  ...  0.017046       NaN       NaN
# 1        NaN -0.007730  0.041877  0.066959  ...  0.105222       NaN       NaN
# 2        NaN  0.099750  0.095358  0.224868  ...  0.031457       NaN       NaN
# 3        NaN  0.032844  0.006765  0.289841  ...  0.021381       NaN       NaN
# 4        NaN  0.095898  0.224174  0.137069  ...  0.017857       NaN       NaN
# 5        NaN  0.024135  0.162219  0.167984  ...  0.167283 -0.082624 -0.021154
# 6        NaN -0.178656  0.155504  0.153620  ...  0.147552       NaN       NaN
# 7        NaN  0.005265  0.036870 -0.127377  ...  0.066856       NaN       NaN
# 8        NaN -0.009085 -0.042723  0.175865  ... -0.008944       NaN       NaN
# 9        NaN -0.058257  0.287813 -0.193437  ... -0.044346       NaN       NaN
#
#      ZNF536    ZNF592    ZNF623    ZNF646   ZSCAN12  CCL4L2  CDK11B
# 0  0.014567  0.161617  0.019846 -0.264657       NaN     NaN     NaN
# 1 -0.022810  0.004996 -0.052879 -0.051166       NaN     NaN     NaN
# 2 -0.131265  0.080008  0.041570 -0.036201       NaN     NaN     NaN
# 3 -0.185839  0.114350  0.047070 -0.188832       NaN     NaN     NaN
# 4  0.000366  0.198231 -0.119213 -0.073809       NaN     NaN     NaN
# 5 -0.087186  0.056861  0.124111 -0.109908 -0.085061     NaN     NaN
# 6 -0.046993  0.322377 -0.088644 -0.172281       NaN     NaN     NaN
# 7 -0.076016  0.044148  0.036761 -0.116984       NaN     NaN     NaN
# 8 -0.045426  0.394939 -0.000253 -0.085085       NaN     NaN     NaN
# 9  0.024208 -0.042170 -0.240379  0.038229       NaN     NaN     NaN
#
# [10 rows x 18538 columns]

# %%
df_renamed = df_raw.rename(columns={
    "depmap_id": "model_id",
    "cell_line_display_name": "cell_line_name",
    "lineage_1": "oncotree_lineage",
    "lineage_2": "oncotree_primary_disease",
    "lineage_3": "oncotree_subtype"
})

df_renamed.head(100)
# Out:
#       model_id cell_line_name   oncotree_lineage  \
# 0   ACH-001270         127399        Soft Tissue
# 1   ACH-002680        170MGBA          CNS/Brain
# 2   ACH-002400          21MT1             Breast
# 3   ACH-002401          21MT2             Breast
# 4   ACH-002399           21NT             Breast
# ..         ...            ...                ...
# 95  ACH-000633           FU97  Esophagus/Stomach
# 96  ACH-002239          H3118      Head and Neck
# 97  ACH-001508           H314      Head and Neck
# 98  ACH-001310           HA1E             Kidney
# 99  ACH-002475           HAP1            Myeloid
#
#                  oncotree_primary_disease  \
# 0                        Synovial Sarcoma
# 1               Adult-Type Diffuse Glioma
# 2               Invasive Breast Carcinoma
# 3               Invasive Breast Carcinoma
# 4               Invasive Breast Carcinoma
# ..                                    ...
# 95         Esophagogastric Adenocarcinoma
# 96                     Salivary Carcinoma
# 97  Head and Neck Squamous Cell Carcinoma
# 98                          Non-Cancerous
# 99           Myeloproliferative Neoplasms
#
#                        oncotree_subtype  lineage_6  lineage_4      A1BG  \
# 0                      Synovial Sarcoma        NaN        NaN -0.038756
# 1            Glioblastoma, IDH-Wildtype        NaN        NaN -0.007730
# 2      Breast Invasive Ductal Carcinoma      HER2+        NaN  0.099750
# 3      Breast Invasive Ductal Carcinoma      HER2+        NaN  0.032844
# 4      Breast Invasive Ductal Carcinoma      HER2+        NaN  0.095898
# ..                                  ...        ...        ...       ...
# 95  Diffuse Type Stomach Adenocarcinoma        NaN        NaN  0.026470
# 96             Mucoepidermoid Carcinoma        NaN        NaN -0.011085
# 97  Oral Cavity Squamous Cell Carcinoma        NaN        NaN  0.085641
# 98   Immortalized Embyonic Kidney Cells        NaN        NaN -0.119890
# 99  Chronic Myeloid Leukemia, BCR-ABL1+  BCR::ABL1        NaN -0.318971
#
#         AASS    ABCA10  ...    ZNF432  ZNF516  ZNF518A    ZNF536    ZNF592  \
# 0  -0.215523  0.044912  ...  0.017046     NaN      NaN  0.014567  0.161617
# 1   0.041877  0.066959  ...  0.105222     NaN      NaN -0.022810  0.004996
# 2   0.095358  0.224868  ...  0.031457     NaN      NaN -0.131265  0.080008
# 3   0.006765  0.289841  ...  0.021381     NaN      NaN -0.185839  0.114350
# 4   0.224174  0.137069  ...  0.017857     NaN      NaN  0.000366  0.198231
# ..       ...       ...  ...       ...     ...      ...       ...       ...
# 95  0.103962  0.149722  ...  0.017910     NaN      NaN  0.031225 -0.061094
# 96  0.189147 -0.124184  ... -0.262401     NaN      NaN -0.164486 -0.512328
# 97  0.008080  0.068033  ...  0.378795     NaN      NaN -0.289145  0.070011
# 98  0.024621  0.256396  ...  0.175133     NaN      NaN  0.128781  0.269691
# 99  0.049382  0.257187  ...  0.095894     NaN      NaN -0.366485  0.067144
#
#       ZNF623    ZNF646  ZSCAN12  CCL4L2  CDK11B
# 0   0.019846 -0.264657      NaN     NaN     NaN
# 1  -0.052879 -0.051166      NaN     NaN     NaN
# 2   0.041570 -0.036201      NaN     NaN     NaN
# 3   0.047070 -0.188832      NaN     NaN     NaN
# 4  -0.119213 -0.073809      NaN     NaN     NaN
# ..       ...       ...      ...     ...     ...
# 95  0.063351 -0.210258      NaN     NaN     NaN
# 96 -0.056615 -0.051226      NaN     NaN     NaN
# 97 -0.029980 -0.013957      NaN     NaN     NaN
# 98 -0.346653 -0.081113      NaN     NaN     NaN
# 99 -0.065370 -0.074677      NaN     NaN     NaN
#
# [100 rows x 18538 columns]

# %%
df_stripped = df_renamed.copy()

df_stripped.insert(
    2,
    "stripped_cell_line_name",
    df_stripped["cell_line_name"]
    .astype(str)
    .apply(lambda x: re.sub(r"[^A-Za-z0-9]", "", x).upper())
)

df_stripped.head()
# Out:
#      model_id cell_line_name stripped_cell_line_name oncotree_lineage  \
# 0  ACH-001270         127399                  127399      Soft Tissue
# 1  ACH-002680        170MGBA                 170MGBA        CNS/Brain
# 2  ACH-002400          21MT1                   21MT1           Breast
# 3  ACH-002401          21MT2                   21MT2           Breast
# 4  ACH-002399           21NT                    21NT           Breast
#
#     oncotree_primary_disease                  oncotree_subtype lineage_6  \
# 0           Synovial Sarcoma                  Synovial Sarcoma       NaN
# 1  Adult-Type Diffuse Glioma        Glioblastoma, IDH-Wildtype       NaN
# 2  Invasive Breast Carcinoma  Breast Invasive Ductal Carcinoma     HER2+
# 3  Invasive Breast Carcinoma  Breast Invasive Ductal Carcinoma     HER2+
# 4  Invasive Breast Carcinoma  Breast Invasive Ductal Carcinoma     HER2+
#
#    lineage_4      A1BG      AASS  ...    ZNF432  ZNF516  ZNF518A    ZNF536  \
# 0        NaN -0.038756 -0.215523  ...  0.017046     NaN      NaN  0.014567
# 1        NaN -0.007730  0.041877  ...  0.105222     NaN      NaN -0.022810
# 2        NaN  0.099750  0.095358  ...  0.031457     NaN      NaN -0.131265
# 3        NaN  0.032844  0.006765  ...  0.021381     NaN      NaN -0.185839
# 4        NaN  0.095898  0.224174  ...  0.017857     NaN      NaN  0.000366
#
#      ZNF592    ZNF623    ZNF646  ZSCAN12  CCL4L2  CDK11B
# 0  0.161617  0.019846 -0.264657      NaN     NaN     NaN
# 1  0.004996 -0.052879 -0.051166      NaN     NaN     NaN
# 2  0.080008  0.041570 -0.036201      NaN     NaN     NaN
# 3  0.114350  0.047070 -0.188832      NaN     NaN     NaN
# 4  0.198231 -0.119213 -0.073809      NaN     NaN     NaN
#
# [5 rows x 18539 columns]

# %%
df_cleaned = df_stripped.drop(
    columns=[c for c in ["lineage_4", "lineage_6"] if c in df_stripped.columns]
)

df_cleaned.head(10)
# Out:
#      model_id cell_line_name stripped_cell_line_name       oncotree_lineage  \
# 0  ACH-001270         127399                  127399            Soft Tissue
# 1  ACH-002680        170MGBA                 170MGBA              CNS/Brain
# 2  ACH-002400          21MT1                   21MT1                 Breast
# 3  ACH-002401          21MT2                   21MT2                 Breast
# 4  ACH-002399           21NT                    21NT                 Breast
# 5  ACH-003587         531MII                  531MII                   Bone
# 6  ACH-000520            59M                     59M   Ovary/Fallopian Tube
# 7  ACH-000973           639V                    639V  Bladder/Urinary Tract
# 8  ACH-001795         94T778                  94T778            Soft Tissue
# 9  ACH-001999        9505BIK                 9505BIK               Pancreas
#
#     oncotree_primary_disease                  oncotree_subtype      A1BG  \
# 0           Synovial Sarcoma                  Synovial Sarcoma -0.038756
# 1  Adult-Type Diffuse Glioma        Glioblastoma, IDH-Wildtype -0.007730
# 2  Invasive Breast Carcinoma  Breast Invasive Ductal Carcinoma  0.099750
# 3  Invasive Breast Carcinoma  Breast Invasive Ductal Carcinoma  0.032844
# 4  Invasive Breast Carcinoma  Breast Invasive Ductal Carcinoma  0.095898
# 5               Osteosarcoma                      Osteosarcoma  0.024135
# 6   Ovarian Epithelial Tumor  High-Grade Serous Ovarian Cancer -0.178656
# 7            Urethral Cancer     Urethral Urothelial Carcinoma  0.005265
# 8                Liposarcoma   Well-Differentiated Liposarcoma -0.009085
# 9  Pancreatic Adenocarcinoma         Pancreatic Adenocarcinoma -0.058257
#
#        AASS    ABCA10     ABCA7  ...    ZNF432    ZNF516   ZNF518A    ZNF536  \
# 0 -0.215523  0.044912  0.208822  ...  0.017046       NaN       NaN  0.014567
# 1  0.041877  0.066959  0.034664  ...  0.105222       NaN       NaN -0.022810
# 2  0.095358  0.224868  0.108875  ...  0.031457       NaN       NaN -0.131265
# 3  0.006765  0.289841 -0.029654  ...  0.021381       NaN       NaN -0.185839
# 4  0.224174  0.137069  0.111254  ...  0.017857       NaN       NaN  0.000366
# 5  0.162219  0.167984  0.038783  ...  0.167283 -0.082624 -0.021154 -0.087186
# 6  0.155504  0.153620  0.127170  ...  0.147552       NaN       NaN -0.046993
# 7  0.036870 -0.127377 -0.036603  ...  0.066856       NaN       NaN -0.076016
# 8 -0.042723  0.175865 -0.080587  ... -0.008944       NaN       NaN -0.045426
# 9  0.287813 -0.193437  0.079831  ... -0.044346       NaN       NaN  0.024208
#
#      ZNF592    ZNF623    ZNF646   ZSCAN12  CCL4L2  CDK11B
# 0  0.161617  0.019846 -0.264657       NaN     NaN     NaN
# 1  0.004996 -0.052879 -0.051166       NaN     NaN     NaN
# 2  0.080008  0.041570 -0.036201       NaN     NaN     NaN
# 3  0.114350  0.047070 -0.188832       NaN     NaN     NaN
# 4  0.198231 -0.119213 -0.073809       NaN     NaN     NaN
# 5  0.056861  0.124111 -0.109908 -0.085061     NaN     NaN
# 6  0.322377 -0.088644 -0.172281       NaN     NaN     NaN
# 7  0.044148  0.036761 -0.116984       NaN     NaN     NaN
# 8  0.394939 -0.000253 -0.085085       NaN     NaN     NaN
# 9 -0.042170 -0.240379  0.038229       NaN     NaN     NaN
#
# [10 rows x 18537 columns]

# %%
meta_cols = [
    "model_id",
    "cell_line_name",
    "stripped_cell_line_name",
    "oncotree_lineage",
    "oncotree_primary_disease",
    "oncotree_subtype"
]

df_final = df_cleaned[
    meta_cols + [c for c in df_cleaned.columns if c not in meta_cols]
]

df_final.tail(10)
# Out:
#         model_id cell_line_name stripped_cell_line_name  \
# 1198  ACH-000502        TCCPAN2                 TCCPAN2
# 1199  ACH-001719         OCIC4P                  OCIC4P
# 1200  ACH-000146           THP1                    THP1
# 1201  ACH-000835            GCT                     GCT
# 1202  ACH-000579        UACC257                 UACC257
# 1203  ACH-001300         CHLA15                  CHLA15
# 1204  ACH-001301        COGN278                 COGN278
# 1205  ACH-001302        COGN305                 COGN305
# 1206  ACH-002687        WM3772F                 WM3772F
# 1207  ACH-000899           WM88                    WM88
#
#                oncotree_lineage  \
# 1198                   Pancreas
# 1199       Ovary/Fallopian Tube
# 1200                    Myeloid
# 1201                Soft Tissue
# 1202                       Skin
# 1203  Peripheral Nervous System
# 1204  Peripheral Nervous System
# 1205  Peripheral Nervous System
# 1206                        Eye
# 1207                       Skin
#
#                                oncotree_primary_disease  \
# 1198                          Pancreatic Adenocarcinoma
# 1199                           Ovarian Epithelial Tumor
# 1200                             Acute Myeloid Leukemia
# 1201  Undifferentiated Pleomorphic Sarcoma/Malignant...
# 1202                                           Melanoma
# 1203                                      Neuroblastoma
# 1204                                      Neuroblastoma
# 1205                                      Neuroblastoma
# 1206                                    Ocular Melanoma
# 1207                                           Melanoma
#
#                                        oncotree_subtype      A1BG      AASS  \
# 1198                          Pancreatic Adenocarcinoma -0.096555 -0.072769
# 1199                          Clear Cell Ovarian Cancer  0.046160  0.067926
# 1200                             Acute Myeloid Leukemia -0.066135 -0.058357
# 1201  Undifferentiated Pleomorphic Sarcoma/Malignant... -0.102978 -0.129353
# 1202                                           Melanoma -0.316214  0.054194
# 1203                                      Neuroblastoma -0.136450  0.385485
# 1204                                      Neuroblastoma  0.093375  0.013202
# 1205                                      Neuroblastoma  0.051621 -0.006120
# 1206                                     Uveal Melanoma -0.047358  0.012525
# 1207                                           Melanoma  0.139922  0.082232
#
#         ABCA10     ABCA7  ...    ZNF432   ZNF516   ZNF518A    ZNF536  \
# 1198  0.008481  0.095592  ...  0.011997  0.15491 -0.149544  0.029212
# 1199  0.178781  0.249581  ...  0.162450      NaN       NaN -0.203705
# 1200  0.105241 -0.062442  ... -0.002840      NaN       NaN  0.084623
# 1201 -0.175774  0.076545  ... -0.002429      NaN       NaN -0.098580
# 1202  0.212278  0.075262  ...  0.120425      NaN       NaN  0.228437
# 1203  0.210994  0.078847  ...  0.006291      NaN       NaN -0.365959
# 1204  0.170836  0.215000  ...  0.008841      NaN       NaN -0.256811
# 1205  0.122982 -0.201685  ... -0.148384      NaN       NaN -0.679353
# 1206  0.312791  0.091236  ...  0.050761      NaN       NaN  0.061011
# 1207  0.262213 -0.164790  ... -0.168160      NaN       NaN  0.304404
#
#         ZNF592    ZNF623    ZNF646   ZSCAN12  CCL4L2  CDK11B
# 1198  0.064925 -0.036807 -0.185654 -0.098699     NaN     NaN
# 1199  0.009853 -0.032795 -0.115673       NaN     NaN     NaN
# 1200  0.104675 -0.041070 -0.151466       NaN     NaN     NaN
# 1201  0.064628 -0.015717 -0.162827       NaN     NaN     NaN
# 1202 -0.212589 -0.048040 -0.020858       NaN     NaN     NaN
# 1203  0.010409 -0.054104 -0.111416       NaN     NaN     NaN
# 1204  0.137836  0.031976 -0.158846       NaN     NaN     NaN
# 1205  0.052943 -0.108811 -0.436249       NaN     NaN     NaN
# 1206 -0.129788 -0.222693 -0.073629       NaN     NaN     NaN
# 1207 -0.400053  0.035793 -0.078525       NaN     NaN     NaN
#
# [10 rows x 18537 columns]

# %%
df_final.to_csv(
    "/content/drive/MyDrive/Breast Cancer Model/depmap_crispr_26Q1.csv",
    index=False
)

# %%
df_breast = df_final[df_final["oncotree_lineage"] == "Breast"]

df_breast.shape
# Out:
# (53, 18537)

# %%
df_breast.to_csv( "/content/drive/MyDrive/Breast Cancer Model/depmap_crispr_26Q1_breast_only.csv",
    index=False)

# %%
df_breast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53 entries, 2 to 952
# Columns: 18537 entries, model_id to CDK11B
# dtypes: float64(18531), object(6)
# memory usage: 7.5+ MB

# %%
df_breast.describe()
# Out:
#             A1BG       AASS     ABCA10      ABCA7      ABCA8      ABCA9  \
# count  53.000000  53.000000  53.000000  53.000000  53.000000  53.000000
# mean    0.032045   0.047876   0.132129   0.075639  -0.035910   0.098269
# std     0.123764   0.124849   0.143619   0.120060   0.125605   0.108908
# min    -0.265143  -0.241560  -0.294978  -0.294960  -0.365346  -0.072994
# 25%    -0.035171  -0.021537   0.045954   0.016569  -0.096675   0.047488
# 50%     0.024969   0.046866   0.123071   0.086392  -0.041239   0.080435
# 75%     0.095898   0.120109   0.236609   0.152618   0.031291   0.143446
# max     0.308417   0.383970   0.495055   0.398723   0.263641   0.412940
#
#            ABCB6      ABCC4      ABCC5      ABCC9  ...     ZNF432    ZNF516  \
# count  53.000000  53.000000  53.000000  53.000000  ...  53.000000  2.000000
# mean   -0.002134   0.134105   0.079725  -0.031278  ...   0.067529 -0.136525
# std     0.105762   0.114471   0.111443   0.113832  ...   0.113327  0.128901
# min    -0.200351  -0.248905  -0.206592  -0.299864  ...  -0.208249 -0.227671
# 25%    -0.055931   0.061452   0.016492  -0.112184  ...   0.004440 -0.182098
# 50%     0.001007   0.126961   0.099669  -0.014453  ...   0.056764 -0.136525
# 75%     0.069227   0.204127   0.143338   0.031280  ...   0.124929 -0.090952
# max     0.201462   0.431879   0.320564   0.338468  ...   0.388754 -0.045379
#
#         ZNF518A     ZNF536     ZNF592     ZNF623     ZNF646   ZSCAN12  CCL4L2  \
# count  2.000000  53.000000  53.000000  53.000000  53.000000  2.000000     0.0
# mean  -0.027157  -0.159969   0.072144   0.028925  -0.094264 -0.179341     NaN
# std    0.036330   0.146317   0.119470   0.119424   0.100810  0.169267     NaN
# min   -0.052846  -0.552817  -0.247941  -0.238343  -0.343629 -0.299031     NaN
# 25%   -0.040002  -0.221615  -0.002239  -0.043832  -0.181221 -0.239186     NaN
# 50%   -0.027157  -0.146003   0.071285   0.041570  -0.095675 -0.179341     NaN
# 75%   -0.014312  -0.071467   0.138517   0.101358  -0.009922 -0.119497     NaN
# max   -0.001468   0.237944   0.399284   0.290313   0.103366 -0.059652     NaN
#
#        CDK11B
# count     0.0
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN
#
# [8 rows x 18531 columns]

# %%
summary_data_breast = df_breast.describe()
summary_data_breast.to_csv("/content/drive/MyDrive/Breast Cancer Model/summary_data_breast.csv")

# %%
df_breast
# Out:
#        model_id cell_line_name stripped_cell_line_name oncotree_lineage  \
# 2    ACH-002400          21MT1                   21MT1           Breast
# 3    ACH-002401          21MT2                   21MT2           Breast
# 4    ACH-002399           21NT                    21NT           Breast
# 17   ACH-000248          AU565                   AU565           Breast
# 25   ACH-000288          BT549                   BT549           Breast
# 32   ACH-000212         CAL120                  CAL120           Breast
# 33   ACH-000856          CAL51                   CAL51           Breast
# 34   ACH-000783          CAMA1                   CAMA1           Breast
# 63   ACH-001820        COLO824                 COLO824           Breast
# 77   ACH-000258         DU4475                  DU4475           Breast
# 78   ACH-000330          EFM19                   EFM19           Breast
# 101  ACH-000374        HCC1143                 HCC1143           Breast
# 102  ACH-000111        HCC1187                 HCC1187           Breast
# 103  ACH-000699        HCC1395                 HCC1395           Breast
# 104  ACH-000277        HCC1419                 HCC1419           Breast
# 105  ACH-000352        HCC1428                 HCC1428           Breast
# 106  ACH-000624        HCC1806                 HCC1806           Breast
# 107  ACH-000223        HCC1937                 HCC1937           Breast
# 108  ACH-000725         HCC202                  HCC202           Breast
# 113  ACH-000276          HCC38                   HCC38           Breast
# 116  ACH-000668          HCC70                   HCC70           Breast
# 123  ACH-000721          HMC18                   HMC18           Breast
# 127  ACH-000148         HS578T                  HS578T           Breast
# 148  ACH-000711          JIMT1                   JIMT1           Breast
# 167  ACH-000028           KPL1                    KPL1           Breast
# 206  ACH-000621       MDAMB157                MDAMB157           Breast
# 207  ACH-000768       MDAMB231                MDAMB231           Breast
# 208  ACH-000934       MDAMB361                MDAMB361           Breast
# 209  ACH-000876       MDAMB415                MDAMB415           Breast
# 210  ACH-000573       MDAMB436                MDAMB436           Breast
# 211  ACH-000910       MDAMB453                MDAMB453           Breast
# 212  ACH-000849       MDAMB468                MDAMB468           Breast
# 226  ACH-001819         MFM223                  MFM223           Breast
# 297  ACH-002179          OCUBM                   OCUBM           Breast
# 362  ACH-000017          SKBR3                   SKBR3           Breast
# 383  ACH-001662        SNU2372                 SNU2372           Breast
# 401  ACH-001388       SUM102PT                SUM102PT           Breast
# 402  ACH-001389     SUM1315MO2              SUM1315MO2           Breast
# 403  ACH-001390       SUM149PT                SUM149PT           Breast
# 404  ACH-001391       SUM159PT                SUM159PT           Breast
# 405  ACH-001392       SUM185PE                SUM185PE           Breast
# 406  ACH-001393       SUM190PT                SUM190PT           Breast
# 407  ACH-001394       SUM229PE                SUM229PE           Breast
# 408  ACH-001396        SUM52PE                 SUM52PE           Breast
# 412  ACH-000147           T47D                    T47D           Breast
# 432  ACH-000554        UACC893                 UACC893           Breast
# 454  ACH-000097          ZR751                   ZR751           Breast
# 497  ACH-001419          VP229                   VP229           Breast
# 685  ACH-001065          EVSAT                   EVSAT           Breast
# 823  ACH-000859        HCC1954                 HCC1954           Breast
# 844  ACH-002499       UACC3199                UACC3199           Breast
# 845  ACH-001683       UACC3133                UACC3133           Breast
# 952  ACH-000019           MCF7                    MCF7           Breast
#
#             oncotree_primary_disease                   oncotree_subtype  \
# 2          Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 3          Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 4          Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 17         Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 25         Invasive Breast Carcinoma     Breast Invasive Carcinoma, NOS
# 32         Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 33         Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 34         Invasive Breast Carcinoma  Breast Invasive Lobular Carcinoma
# 63              Breast Neoplasm, NOS               Breast Neoplasm, NOS
# 77         Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 78         Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 101        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 102        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 103        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 104        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 105        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 106  Breast Ductal Carcinoma In Situ    Breast Ductal Carcinoma In Situ
# 107        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 108  Breast Ductal Carcinoma In Situ    Breast Ductal Carcinoma In Situ
# 113        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 116        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 123        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 127        Invasive Breast Carcinoma     Breast Invasive Carcinoma, NOS
# 148        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 167        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 206        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 207        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 208        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 209        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 210        Invasive Breast Carcinoma     Breast Invasive Carcinoma, NOS
# 211        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 212        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 226        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 297        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 362        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 383        Invasive Breast Carcinoma        Breast Invasive Cancer, NOS
# 401        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 402        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 403        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 404        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 405        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 406        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 407        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 408        Invasive Breast Carcinoma          Invasive Breast Carcinoma
# 412        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 432        Invasive Breast Carcinoma  Breast Invasive Lobular Carcinoma
# 454        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 497        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 685        Invasive Breast Carcinoma  Breast Invasive Lobular Carcinoma
# 823        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 844        Invasive Breast Carcinoma   Breast Invasive Ductal Carcinoma
# 845        Invasive Breast Carcinoma  Breast Invasive Lobular Carcinoma
# 952        Invasive Breast Carcinoma          Invasive Breast Carcinoma
#
#          A1BG      AASS    ABCA10     ABCA7  ...    ZNF432    ZNF516  \
# 2    0.099750  0.095358  0.224868  0.108875  ...  0.031457       NaN
# 3    0.032844  0.006765  0.289841 -0.029654  ...  0.021381       NaN
# 4    0.095898  0.224174  0.137069  0.111254  ...  0.017857       NaN
# 17   0.015512  0.120109  0.224513  0.152618  ...  0.153300       NaN
# 25  -0.040132  0.076327  0.037691 -0.111315  ...  0.004437       NaN
# 32  -0.224557  0.051089  0.119816  0.045506  ...  0.056764       NaN
# 33  -0.260047  0.039616  0.030947 -0.080077  ...  0.124929       NaN
# 34  -0.265143  0.198032  0.069421  0.031427  ...  0.004440       NaN
# 63   0.150548 -0.099634  0.045954  0.016569  ...  0.103810       NaN
# 77  -0.101480  0.164918  0.059257 -0.001245  ...  0.260129       NaN
# 78   0.064534 -0.046528  0.083626 -0.238985  ...  0.044021       NaN
# 101 -0.048027 -0.026729  0.238416  0.216496  ... -0.063920       NaN
# 102 -0.035171 -0.061580  0.171643  0.178411  ... -0.044439       NaN
# 103 -0.003637  0.165554  0.285459  0.074680  ...  0.016101       NaN
# 104  0.071726 -0.097329  0.006459  0.214784  ...  0.131270       NaN
# 105  0.002651 -0.013074  0.198136  0.089356  ...  0.106248       NaN
# 106  0.105734  0.052702  0.121166  0.093750  ...  0.114694       NaN
# 107  0.040401  0.049745  0.027514  0.159451  ...  0.007505       NaN
# 108  0.229081  0.059139  0.207254  0.203648  ... -0.034014       NaN
# 113  0.308417  0.008065  0.283662  0.127051  ... -0.049296       NaN
# 116 -0.066573  0.208535  0.239882  0.123875  ... -0.001308       NaN
# 123 -0.118403 -0.044788 -0.046929 -0.057418  ...  0.091337       NaN
# 127  0.024969  0.104265  0.236609  0.083109  ... -0.033185       NaN
# 148  0.030582 -0.015360  0.123071  0.066063  ...  0.128224       NaN
# 167 -0.098422  0.108780  0.275201  0.157206  ...  0.112534       NaN
# 206  0.050030  0.071800  0.122072  0.178744  ...  0.076347       NaN
# 207  0.126126  0.025761  0.043159  0.180319  ...  0.129422       NaN
# 208  0.301333  0.197237  0.054488 -0.038291  ... -0.170860       NaN
# 209  0.119867  0.225163  0.084464  0.147039  ...  0.099697       NaN
# 210 -0.080118  0.084248 -0.041657  0.008715  ...  0.082790       NaN
# 211 -0.032958  0.181662  0.093483  0.081952  ...  0.023193       NaN
# 212 -0.088370  0.060077  0.215403  0.142400  ...  0.003633       NaN
# 226  0.025125 -0.011409  0.057539  0.110845  ...  0.146008       NaN
# 297  0.122624  0.315490  0.201744  0.033838  ...  0.245514       NaN
# 362  0.012094  0.046745  0.156589  0.097070  ...  0.138080       NaN
# 383 -0.017635  0.008557  0.354573 -0.099536  ... -0.120959       NaN
# 401 -0.005974 -0.021537  0.096063  0.043050  ...  0.120104       NaN
# 402  0.021703 -0.011960  0.306932 -0.047761  ...  0.139216       NaN
# 403 -0.020968 -0.241560  0.253999 -0.294960  ... -0.046480       NaN
# 404  0.017542 -0.103907 -0.221708  0.168791  ...  0.114813       NaN
# 405  0.162881 -0.235417 -0.294978  0.093778  ...  0.291143       NaN
# 406  0.069925  0.078454  0.128308  0.080813  ...  0.006558       NaN
# 407  0.061449 -0.161492  0.495055  0.219064  ...  0.056916       NaN
# 408  0.297120  0.000187  0.306127 -0.077112  ...  0.353746       NaN
# 412 -0.037789 -0.076369 -0.059642  0.052179  ...  0.029112 -0.227671
# 432  0.289909 -0.061384  0.234664  0.197967  ... -0.208249       NaN
# 454 -0.001109  0.046866  0.024623  0.061578  ...  0.031638 -0.045379
# 497  0.086313 -0.021294  0.113939  0.131000  ...  0.021050       NaN
# 685  0.047807  0.383970  0.274996  0.079479  ...  0.044288       NaN
# 823  0.042562  0.160270 -0.022459  0.260456  ...  0.199428       NaN
# 844  0.162070 -0.076755 -0.115934  0.086392  ...  0.096327       NaN
# 845 -0.005625  0.146999  0.167125 -0.023105  ... -0.016479       NaN
# 952 -0.038621  0.198866  0.283324  0.398723  ...  0.388754       NaN
#
#       ZNF518A    ZNF536    ZNF592    ZNF623    ZNF646   ZSCAN12  CCL4L2  \
# 2         NaN -0.131265  0.080008  0.041570 -0.036201       NaN     NaN
# 3         NaN -0.185839  0.114350  0.047070 -0.188832       NaN     NaN
# 4         NaN  0.000366  0.198231 -0.119213 -0.073809       NaN     NaN
# 17        NaN -0.442361  0.222999  0.104696 -0.055229       NaN     NaN
# 25        NaN -0.217315  0.032526  0.055509 -0.054651       NaN     NaN
# 32        NaN -0.257963  0.162809 -0.084783 -0.187303       NaN     NaN
# 33        NaN -0.097443  0.055771 -0.229531  0.043913       NaN     NaN
# 34        NaN -0.179687  0.186390 -0.238343 -0.016217       NaN     NaN
# 63        NaN  0.237944 -0.128069  0.134434  0.035589       NaN     NaN
# 77        NaN -0.296707  0.025623  0.061624 -0.025559       NaN     NaN
# 78        NaN -0.406743  0.278238  0.087814 -0.181221       NaN     NaN
# 101       NaN -0.180558  0.076170  0.023468 -0.205163       NaN     NaN
# 102       NaN -0.066131  0.071285 -0.110220  0.011920       NaN     NaN
# 103       NaN -0.188855  0.031259  0.201704  0.047580       NaN     NaN
# 104       NaN  0.026272  0.238627  0.002219 -0.102066       NaN     NaN
# 105       NaN -0.179624 -0.029394 -0.163137 -0.249430       NaN     NaN
# 106       NaN -0.130228  0.007571  0.101358 -0.130550       NaN     NaN
# 107       NaN -0.223400  0.059095 -0.031537  0.001975       NaN     NaN
# 108       NaN -0.092462  0.118023  0.011459 -0.213017       NaN     NaN
# 113       NaN -0.117412  0.151558  0.116884 -0.164046       NaN     NaN
# 116       NaN -0.072394  0.084145 -0.050230  0.011401       NaN     NaN
# 123       NaN -0.011780 -0.033803  0.070876 -0.104506       NaN     NaN
# 127       NaN -0.193546 -0.023184  0.052571  0.016261       NaN     NaN
# 148       NaN -0.035234  0.003446  0.041498 -0.129761       NaN     NaN
# 167       NaN -0.249799 -0.247941  0.143068 -0.022361       NaN     NaN
# 206       NaN -0.205016 -0.066510 -0.043832 -0.157664       NaN     NaN
# 207       NaN -0.436305 -0.021956  0.090498 -0.114482       NaN     NaN
# 208       NaN -0.018370 -0.025752 -0.092536  0.048208       NaN     NaN
# 209       NaN -0.351223  0.399284  0.161087 -0.114479       NaN     NaN
# 210       NaN -0.176880  0.070724  0.254523 -0.128944       NaN     NaN
# 211       NaN -0.083177  0.138517  0.058224  0.005767       NaN     NaN
# 212       NaN -0.071467 -0.051239 -0.088025 -0.244429       NaN     NaN
# 226       NaN  0.028268  0.019048 -0.111034 -0.146381       NaN     NaN
# 297       NaN -0.058131  0.246501  0.243082 -0.162354       NaN     NaN
# 362       NaN -0.118347  0.231385  0.038881 -0.199700       NaN     NaN
# 383       NaN -0.184405 -0.002239 -0.033515 -0.006101       NaN     NaN
# 401       NaN -0.260886 -0.087296 -0.065428 -0.166953       NaN     NaN
# 402       NaN  0.000107  0.110185  0.111081 -0.049639       NaN     NaN
# 403       NaN -0.071332  0.190182  0.290313  0.078030       NaN     NaN
# 404       NaN -0.097082 -0.064098 -0.089890 -0.343629       NaN     NaN
# 405       NaN -0.428197  0.011948  0.003915 -0.206918       NaN     NaN
# 406       NaN -0.282439  0.097830  0.043610  0.009406       NaN     NaN
# 407       NaN -0.099207  0.019063 -0.023016  0.103366       NaN     NaN
# 408       NaN -0.091880  0.105836  0.126392 -0.190706       NaN     NaN
# 412 -0.052846 -0.206542 -0.124932 -0.033386 -0.095675 -0.059652     NaN
# 432       NaN  0.096851 -0.027921 -0.022316 -0.009922       NaN     NaN
# 454 -0.001468 -0.221615  0.119128 -0.033646 -0.069677 -0.299031     NaN
# 497       NaN -0.395507  0.071352  0.069479 -0.075854       NaN     NaN
# 685       NaN -0.127228  0.308542  0.121579 -0.048506       NaN     NaN
# 823       NaN -0.194470  0.107589  0.097283 -0.053373       NaN     NaN
# 844       NaN -0.552817  0.059697  0.078164 -0.229242       NaN     NaN
# 845       NaN -0.146003  0.168232 -0.172566 -0.247055       NaN     NaN
# 952       NaN -0.032916  0.084825  0.283273 -0.207801       NaN     NaN
#
#      CDK11B
# 2       NaN
# 3       NaN
# 4       NaN
# 17      NaN
# 25      NaN
# 32      NaN
# 33      NaN
# 34      NaN
# 63      NaN
# 77      NaN
# 78      NaN
# 101     NaN
# 102     NaN
# 103     NaN
# 104     NaN
# 105     NaN
# 106     NaN
# 107     NaN
# 108     NaN
# 113     NaN
# 116     NaN
# 123     NaN
# 127     NaN
# 148     NaN
# 167     NaN
# 206     NaN
# 207     NaN
# 208     NaN
# 209     NaN
# 210     NaN
# 211     NaN
# 212     NaN
# 226     NaN
# 297     NaN
# 362     NaN
# 383     NaN
# 401     NaN
# 402     NaN
# 403     NaN
# 404     NaN
# 405     NaN
# 406     NaN
# 407     NaN
# 408     NaN
# 412     NaN
# 432     NaN
# 454     NaN
# 497     NaN
# 685     NaN
# 823     NaN
# 844     NaN
# 845     NaN
# 952     NaN
#
# [53 rows x 18537 columns]

# %%
# Get the gene columns (all columns except the first 6 metadata columns)
gene_columns = df_breast.columns[6:]

print(f"Number of genes: {len(gene_columns)}")
print(f"First few gene names: {list(gene_columns[:5])}")
# Out:
# Number of genes: 18531
# First few gene names: ['A1BG', 'AASS', 'ABCA10', 'ABCA7', 'ABCA8']

# %%
# Calculate mean gene effects for breast cancer
breast_gene_means = df_breast[gene_columns].mean()

print(f"\nMean gene effects calculated for {len(breast_gene_means)} genes")
print(f"Example - A1BG mean effect: {breast_gene_means['A1BG']:.4f}")
# Out:
# Mean gene effects calculated for 18531 genes
# Example - A1BG mean effect: 0.0320

# %%
breast_gene_means.sort_values()
# Out:
# RPL15     -5.329407
# SNRPD3    -5.224486
# RAN       -4.327291
# HSPE1     -3.770625
# RPL17     -3.621755
#              ...
# SYT15           NaN
# FAM86B1         NaN
# OR3A3           NaN
# CCL4L2          NaN
# CDK11B          NaN
# Length: 18531, dtype: float64

# %%
df_essential_gene = breast_gene_means.reset_index()
df_essential_gene.columns = ["Gene", "Mean_Dependency"]
df_essential_gene = df_essential_gene.sort_values(by='Mean_Dependency', ascending=True)
df_essential_gene.head()
# Out:
#          Gene  Mean_Dependency
# 13498   RPL15        -5.329407
# 13851  SNRPD3        -5.224486
# 12653     RAN        -4.327291
# 7449    HSPE1        -3.770625
# 13499   RPL17        -3.621755

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get the top 20 genes with the most negative mean dependency
bottom_20_genes = df_essential_gene.head(20)

# Create the bar plot
plt.figure(figsize=(12, 7))

sns.barplot(
    x='Gene',
    y='Mean_Dependency',
    data=bottom_20_genes,
    palette='Reds_d'
)

plt.title('Top 20 Genes with Most Negative Mean Dependency in Breast Cancer Cell Lines')
plt.xlabel('Gene')
plt.ylabel('Mean Dependency Score')

plt.xticks(rotation=45, ha='right')

plt.tight_layout()

# SAVE FIGURE
plt.savefig(
    "/content/drive/MyDrive/Breast Cancer Model/top20_essential_genes.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()
# Out:
# /tmp/ipykernel_1013/2636601464.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
df_essential_gene.to_csv(
    "/content/drive/MyDrive/Breast Cancer Model/essentiality_mean_dependency_scores.csv",
    index=False)

# %%
plt.savefig(
    "/content/drive/MyDrive/Breast Cancer Model/top20_essential_genes.png",
    dpi=300,
    bbox_inches='tight'
)
